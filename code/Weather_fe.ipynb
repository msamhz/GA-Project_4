# %%
# Import required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime


# Import train_test_split.
from sklearn.linear_model import LogisticRegression

# Import logistic regression

# %%
merge_df = pd.read_csv('../data/merged_train_outer.csv')


merge_df['date']=pd.to_datetime(merge_df['date'])
merge_df['month'] = merge_df['date'].dt.month

# %%
merge_df.groupby('year')[['wnvcount', 'wnvpresent']].sum()
# Out:
#       wnvcount  wnvpresent
# year
# 2007     236.0       189.0
# 2009      19.0        19.0
# 2011      57.0        50.0
# 2013     239.0       199.0

# %%
merge_df['hl'] = merge_df['year'].map(lambda x : 1 if x in [2007, 2013] else 0)

# %%
# Only July values

train_1 = merge_df.loc[merge_df['month']==7,:]

# %%
x = train_1[['tmin', 'tavg', 'dewpoint', 'wetbulb', 'heat', 'cool',
       'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
       'avgspeed', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+',
       'fu', 'hz', 'mi', 'ra', 'sn', 'sq', 'ts', 'vc']]
y = train_1['hl']

# %%
# Step 2: Instantiate our model.
logreg = LogisticRegression()

# Step 3: Fit our model.
logreg.fit(x, y)
# Out:
# C:\Users\User\.conda\envs\dsi\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x, y)
# Out:
# 0.8658271819366045

# %%
pd.DataFrame(data = logreg.coef_,
             columns = list(x.columns)).T.sort_values(0)
# Out:
#                     0
# ra          -2.116575
# heat        -1.570892
# ts          -1.366597
# tmin        -0.662519
# resultspeed -0.514647
# sunrise     -0.385884
# sunset      -0.162764
# resultdir   -0.075559
# fg          -0.008299
# dewpoint    -0.003638
# sq           0.000000
# bc           0.000000
# sn           0.000000
# fg+          0.000000
# mi           0.000000
# fu           0.033624
# dz           0.039128
# wetbulb      0.059064
# tavg         0.108419
# cool         0.322531
# sealevel     0.460507
# stnpressure  0.505640
# avgspeed     1.235068
# br           1.556059
# hz           1.558687
# vc           1.569993
# preciptotal  1.826033

# %%
train_1.groupby('hl').mean().T
# Out:
# hl                      0            1
# latitude        41.844712    41.853466
# longitude      -87.698675   -87.696181
# nummosquitos    15.024348    21.109937
# wnvpresent       0.013043     0.027484
# wnvcount         0.013913     0.031712
# station          1.789936     1.781161
# sprayed          0.000000     0.001057
# tmax            83.685304    83.703140
# tmin            66.540735    65.170314
# tavg            75.113019    74.436727
# dewpoint        60.692492    60.098002
# wetbulb         66.169329    65.853473
# heat             0.122204     0.012369
# cool            10.448083     9.640343
# preciptotal      0.088291     0.213121
# stnpressure     29.254177    29.294462
# sealevel        29.908027    29.956736
# resultspeed      5.759185     7.320266
# resultdir       21.787540    21.406280
# avgspeed         7.298802     9.028925
# month            7.000000     7.000000
# sunrise          4.547870     4.507199
# sunset          19.375413    19.408389
# bc               0.000000     0.000000
# br               0.262780     0.352046
# dz               0.002396     0.003806
# fg               0.000799     0.000000
# fg+              0.000000     0.000000
# fu               0.001597     0.002854
# hz               0.080671     0.206470
# mi               0.000000     0.000000
# ra               0.448882     0.307326
# sn               0.000000     0.000000
# sq               0.000000     0.000000
# ts               0.235623     0.267364
# vc               0.001597     0.113225
# gr               0.000000     0.000000
# year          2009.931310  2010.099905

# %%
train_1.loc[(train_1['hl']==1) & train_1['preciptotal']>0, 'preciptotal'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
train_1.loc[(train_1['hl']==0) & train_1['preciptotal']>0, 'preciptotal'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# Only August values

train_1 = merge_df.loc[merge_df['month']==8,:]

x = train_1[['tmin', 'tavg', 'dewpoint', 'wetbulb', 'heat', 'cool',
       'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
       'avgspeed', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+',
       'fu', 'hz', 'mi', 'ra', 'sn', 'sq', 'ts', 'vc']]
y = train_1['hl']

# %%
# Step 2: Instantiate our model.
logreg = LogisticRegression()

# Step 3: Fit our model.
logreg.fit(x, y)
# Out:
# C:\Users\User\.conda\envs\dsi\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x, y)
# Out:
# 0.7823290453622207

# %%
pd.DataFrame(data = logreg.coef_,
             columns = list(x.columns)).T.sort_values(0)
# Out:
#                     0
# ra          -1.154160
# resultspeed -1.123551
# stnpressure -0.330432
# sunrise     -0.239914
# dewpoint    -0.198106
# sealevel    -0.181503
# cool        -0.123829
# sunset      -0.109036
# wetbulb     -0.083070
# heat        -0.076294
# sq           0.000000
# mi           0.000000
# bc           0.000000
# fu           0.000000
# sn           0.000000
# fg+          0.000000
# dz           0.009744
# resultdir    0.084208
# tmin         0.176677
# vc           0.278492
# tavg         0.293523
# preciptotal  0.537193
# fg           0.790232
# br           1.201988
# avgspeed     1.308351
# hz           1.730058
# ts           2.228851

# %%
train_1.groupby('hl').mean().T
# Out:
# hl                      0            1
# latitude        41.838841    41.837138
# longitude      -87.697361   -87.685539
# nummosquitos     6.874515    26.667678
# wnvpresent       0.034929     0.139605
# wnvcount         0.042691     0.174001
# station          1.788876     1.832127
# sprayed          0.000000     0.004552
# tmax            81.269012    84.071394
# tmin            64.592509    68.035215
# tavg            72.930760    76.053304
# dewpoint        60.346198    63.998070
# wetbulb         65.363224    68.339122
# heat             0.048808     0.001447
# cool             8.284904    11.298119
# preciptotal      0.112236     0.191539
# stnpressure     29.314132    29.255494
# sealevel        29.979546    29.935953
# resultspeed      5.519750     4.977279
# resultdir       15.037457    17.382537
# avgspeed         6.616005     6.768307
# month            8.000000     8.000000
# sunrise          4.991695     4.958201
# sunset          18.878415    18.917575
# bc               0.000000     0.000000
# br               0.223610     0.399904
# dz               0.002270     0.006271
# fg               0.001135     0.041968
# fg+              0.000000     0.000000
# fu               0.000000     0.000000
# hz               0.005675     0.106126
# mi               0.000000     0.000000
# ra               0.256527     0.348288
# sn               0.000000     0.000000
# sq               0.000000     0.000000
# ts               0.013621     0.321756
# vc               0.000000     0.070429
# gr               0.001135     0.000000
# year          2010.139614  2009.208394
