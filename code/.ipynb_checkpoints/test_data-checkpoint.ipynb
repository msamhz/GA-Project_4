# %%
# Import required packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import datetime


# Import train_test_split.
from sklearn.linear_model import LogisticRegression

# Import logistic regression

# %%
# Import Data

train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
# Potential features to engineer

# %%
merge_df = pd.read_csv('../data/merged_train_outer.csv')

# %%
# match traps
train = pd.read_csv('../data/train.csv')
train.columns = [x.lower() for x in list(train.columns)]

# find traps
trap = train[['trap', 'longitude', 'latitude']]
trap = trap.groupby(['trap', 'longitude', 'latitude'], as_index=False).count()

# %%
# create basic features
# Out:
# (10506, 3)

# %%
# create basic features

merge_df['date']=pd.to_datetime(merge_df['date'])
merge_df['month'] = merge_df['date'].dt.month
merge_df['week'] = merge_df['date'].dt.week

merge_df = merge_df.merge(trap, how='left', on = ['latitude', 'longitude'])
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_26400/253571204.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   merge_df['week'] = merge_df['date'].dt.week

# %%
merge_df = merge_df.merge(trap, how='left', on = ['latitude', 'longitude'])
#merge_df_1 = merge_df.loc[merge_df['year'].isin([2007, 2013]), :].copy()
#merge_df_1['hl'] = merge_df_1['year'].map(lambda x : 1 if x == 2013 else 0)
merge_df['hl'] = merge_df['year'].map(lambda x : 1 if x in [2007, 2013] else 0)

# merge_df['jul'] = merge_df['month'].map(lambda x : 1 if x == 7 else 0)
# merge_df['jul_int'] = merge_df['jul']*merge_df['preciptotal']

# %%
merge_df.shape
# Out:
# (9772, 44)

# %%
# inspect location hotspots

mos_loc = merge_df.groupby(['trap', 'year'], as_index=False)[['wnvpresent', 'wnvcount']]\
.sum().sort_values(['year','wnvpresent'], ascending=False)

# %%
mos_loc
# Out:
#      trap  year  wnvpresent  wnvcount
# 339  T900  2013        15.0      46.0
# 32   T013  2013         8.0       8.0
# 311  T225  2013         8.0       8.0
# 8    T003  2013         7.0       7.0
# 57   T030  2013         7.0       8.0
# ..    ...   ...         ...       ...
# 261  T157  2007         0.0       0.0
# 273  T161  2007         0.0       0.0
# 278  T206  2007         0.0       0.0
# 288  T218  2007         0.0       0.0
# 291  T219  2007         0.0       0.0
#
# [343 rows x 4 columns]

# %%
top = mos_loc.groupby(['year', 'trap'], as_index=False)[['wnvpresent', 'wnvcount']].sum().sort_values(['wnvcount'], ascending=False)

# %%
top.head()
# Out:
#      year  trap  wnvpresent  wnvcount
# 341  2013  T900        15.0      46.0
# 80   2007  T115        12.0      36.0
# 267  2011  T900        12.0      18.0
# 84   2007  T138         9.0      16.0
# 81   2007  T128         5.0       9.0

# %%
t0713 = top.loc[top['year'] == 2007, :][:10]['trap'].values

# %%
t0713_2 = top.loc[top['year'] == 2013, :][:10]['trap'].values

# %%
t0713 = list(t0713)
t0713.extend(list(t0713_2))

# %%
top.loc[top['year'] == 2009, :][:10]
# Out:
#      year  trap  wnvpresent  wnvcount
# 187  2009  T900         2.0       2.0
# 188  2009  T903         2.0       2.0
# 154  2009  T095         2.0       2.0
# 128  2009  T031         1.0       1.0
# 181  2009  T225         1.0       1.0
# 152  2009  T090         1.0       1.0
# 155  2009  T102         1.0       1.0
# 186  2009  T230         1.0       1.0
# 184  2009  T228         1.0       1.0
# 177  2009  T221         1.0       1.0

# %%
top.loc[top['year'] == 2011, :][:10]
# Out:
#      year  trap  wnvpresent  wnvcount
# 267  2011  T900        12.0      18.0
# 268  2011  T903         7.0       8.0
# 253  2011  T223         5.0       5.0
# 190  2011  T003         3.0       3.0
# 231  2011  T114         2.0       2.0
# 249  2011  T218         2.0       2.0
# 240  2011  T151         2.0       2.0
# 255  2011  T225         2.0       2.0
# 198  2011  T027         1.0       1.0
# 222  2011  T081         1.0       1.0

# %%
top30 = list(set(top30))

# %%
mos_loc.groupby(['trap', 'year'])[['wnvpresent', 'wnvcount']].sum().sort_values(['wnvcount', 'year'], ascending=False)[:30]
# Out:
#            wnvpresent  wnvcount
# trap year
# T900 2013        15.0      46.0
# T115 2007        12.0      36.0
# T900 2011        12.0      18.0
# T138 2007         9.0      16.0
# T128 2007         5.0       9.0
# T002 2013         6.0       8.0
# T013 2013         8.0       8.0
# T030 2013         7.0       8.0
# T225 2013         8.0       8.0
# T903 2011         7.0       8.0
# T002 2007         7.0       8.0
# T086 2007         7.0       8.0
# T003 2013         7.0       7.0
# T233 2013         6.0       7.0
# T235 2013         7.0       7.0
# T011 2007         7.0       7.0
# T016 2007         5.0       7.0
# T135 2007         7.0       7.0
# T027 2013         6.0       6.0
# T028 2013         6.0       6.0
# T054 2013         5.0       6.0
# T082 2007         6.0       6.0
# T096 2007         5.0       6.0
# T103 2007         4.0       6.0
# T143 2007         5.0       6.0
# T009 2013         4.0       5.0
# T066 2013         5.0       5.0
# T228 2013         5.0       5.0
# T230 2013         5.0       5.0
# T223 2011         5.0       5.0

# %%
train_1 = merge_df.loc[merge_df['month']==9,:]
#train_1 = merge_df.copy()

# %%
x = train_1[['tmin', 'tavg', 'dewpoint', 'wetbulb', 'heat', 'cool',
       'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
       'avgspeed', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+',
       'fu', 'hz', 'mi', 'ra', 'sn', 'sq', 'ts', 'vc']]
y = train_1['hl']

# %%
#t1 = train_1[['tmin', 'tavg', 'dewpoint', 'wetbulb', 'heat', 'cool',
#       'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
#       'avgspeed', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+',
#       'fu', 'hz', 'mi', 'ra', 'sn', 'sq', 'ts', 'vc', 'hl']]

# %%
# Step 2: Instantiate our model.
logreg = LogisticRegression()

# Step 3: Fit our model.
logreg.fit(x, y)
# Out:
# C:\Users\User\.conda\envs\dsi\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x, y)
# Out:
# 0.9925650557620818

# %%
pd.DataFrame(data = logreg.coef_,
             columns = list(x.columns)).T.sort_values(0)
# Out:
#                     0
# avgspeed    -1.006487
# tavg        -0.731368
# sunset      -0.198486
# ra          -0.187303
# dewpoint    -0.176550
# stnpressure -0.171305
# sealevel    -0.098845
# heat        -0.043750
# br          -0.041740
# preciptotal -0.041444
# hz          -0.000002
# sn           0.000000
# mi           0.000000
# sq           0.000000
# fu           0.000000
# fg+          0.000000
# fg           0.000000
# vc           0.000000
# bc           0.000000
# ts           0.000000
# sunrise      0.000758
# dz           0.003395
# resultdir    0.059851
# wetbulb      0.123255
# cool         0.471857
# resultspeed  0.750005
# tmin         1.163361

# %%
train_1.groupby(['hl', 'week']).mean().T
# Out:
# hl                      0            1
# week                   36           36
# latitude        41.826153    41.851946
# longitude      -87.676025   -87.701415
# nummosquitos    23.858824    20.573770
# wnvpresent       0.105882     0.204918
# wnvcount         0.117647     0.262295
# station          1.844444     1.776119
# sprayed          0.000000     0.000000
# tmax            89.050000    84.694030
# tmin            69.005556    61.179104
# tavg            79.027778    72.936567
# dewpoint        61.150000    55.850746
# wetbulb         67.888889    63.238806
# heat             0.000000     0.000000
# cool            14.383333     8.425373
# preciptotal      0.016000     0.000075
# stnpressure     29.311833    29.420597
# sealevel        29.964333    30.101642
# resultspeed      5.286111     4.613433
# resultdir       21.150000    17.432836
# avgspeed         6.733889     6.206716
# month            9.000000     9.000000
# sunrise          5.345278     5.364925
# sunset          18.351204    18.319403
# bc               0.000000     0.000000
# br               0.011111     0.000000
# dz               0.000000     0.000000
# fg               0.000000     0.000000
# fg+              0.000000     0.000000
# fu               0.000000     0.000000
# hz               0.144444     0.000000
# mi               0.000000     0.000000
# ra               0.150000     0.000000
# sn               0.000000     0.000000
# sq               0.000000     0.000000
# ts               0.138889     0.000000
# vc               0.000000     0.000000
# gr               0.000000     0.000000
# year          2007.000000  2013.000000

# %%
t1.loc[(t1['hl']==1) & t1['preciptotal']>0, 'preciptotal'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
t1.loc[(t1['hl']==0) & t1['preciptotal']>0, 'preciptotal'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
train_1 = merge_df.loc[merge_df['month']==8,:]

x = train_1[['tmin', 'tavg', 'dewpoint', 'wetbulb', 'heat', 'cool',
       'preciptotal', 'stnpressure', 'sealevel', 'resultspeed', 'resultdir',
       'avgspeed', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+',
       'fu', 'hz', 'mi', 'ra', 'sn', 'sq', 'ts', 'vc']]
y = train_1['hl']

# %%
# Step 2: Instantiate our model.
logreg = LogisticRegression()

# Step 3: Fit our model.
logreg.fit(x, y)
# Out:
# C:\Users\User\.conda\envs\dsi\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x, y)
# Out:
# 0.7823290453622207

# %%
pd.DataFrame(data = logreg.coef_,
             columns = list(x.columns)).T.sort_values(0)
# Out:
#                     0
# ra          -1.154160
# resultspeed -1.123551
# stnpressure -0.330432
# sunrise     -0.239914
# dewpoint    -0.198106
# sealevel    -0.181503
# cool        -0.123829
# sunset      -0.109036
# wetbulb     -0.083070
# heat        -0.076294
# sq           0.000000
# mi           0.000000
# bc           0.000000
# fu           0.000000
# sn           0.000000
# fg+          0.000000
# dz           0.009744
# resultdir    0.084208
# tmin         0.176677
# vc           0.278492
# tavg         0.293523
# preciptotal  0.537193
# fg           0.790232
# br           1.201988
# avgspeed     1.308351
# hz           1.730058
# ts           2.228851

# %%
train_1.groupby(['hl', 'week']).mean().T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26400/2743286036.py in <module>
# ----> 1 train_1.groupby(['hl', 'week']).mean().T
#
# ~\.conda\envs\dsi\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7704         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7705         # "Union[bool, NoDefault]"; expected "bool"
# -> 7706         return DataFrameGroupBy(
#    7707             obj=self,
#    7708             keys=by,
#
# ~\.conda\envs\dsi\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
#     881
# --> 882             grouper, exclusions, obj = get_grouper(
#     883                 obj,
#     884                 keys,
#
# ~\.conda\envs\dsi\lib\site-packages\pandas\core\groupby\grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880                 in_axis, level, gpr = False, gpr, None
#     881             else:
# --> 882                 raise KeyError(gpr)
#     883         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884             # Add key to exclusions
#
# KeyError: 'week'

# %%
train_1[['ra', 'preciptotal']]
# Out:
#       ra  preciptotal
# 657    0         0.00
# 658    0         0.00
# 659    0         0.00
# 660    0         0.00
# 661    0         0.00
# ...   ..          ...
# 9653   0         0.00
# 9654   0         0.36
# 9655   1         0.47
# 9656   1         0.07
# 9657   1         0.96
#
# [2954 rows x 2 columns]

# %%
merge_df = pd.read_csv('../data/merged_train_outer.csv')

# %%
train_1 = merge_df.copy()

# %%
train_1 = merge_df.loc[merge_df['trap'].isin(t0713),:].copy()

# %%
co = ['date', 'latitude', 'longitude', 'station', 'sprayed', 'tmax', 'tmin', 'tavg',
       'dewpoint', 'wetbulb', 'heat', 'cool', 'codesum', 'preciptotal',
       'stnpressure', 'sealevel', 'resultspeed', 'resultdir', 'avgspeed',
       'month', 'sunrise', 'sunset', 'bc', 'br', 'dz', 'fg', 'fg+', 'fu', 'hz',
       'mi', 'ra', 'sn', 'sq', 'ts', 'vc', 'gr', 'year', 'trap']

# %%
train_2= train_1.drop('species', axis=1)

train_2 = train_2.groupby(co, as_index=False).sum()

# %%
train_2['wnvpresent'] = train_2['wnvpresent'].map(lambda x: 1 if x > 0 else 0)

# %%
train_2['date'] = pd.to_datetime(train_2['date'])
train_2['month'] = train_2['date'].dt.month
train_2['week'] = train_2['date'].dt.week
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_26400/1882689885.py:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   train_2['week'] = train_2['date'].dt.week

# %%
train_2['week']
# Out:
# 0       22
# 1       22
# 2       22
# 3       22
# 4       23
#         ..
# 1540    39
# 1541    39
# 1542    39
# 1543    39
# 1544    39
# Name: week, Length: 1545, dtype: int64

# %%
train_3 = train_2.loc[train_2['month']==8,:]

# %%
train_4 = train_2.loc[train_2['year'].isin([2007, 2013]),:]
train_4.groupby(['year', 'month','week'], as_index=False)[['wnvcount']].sum()[0:35]
# Out:
#     year  month  week  wnvcount
# 0   2007      5    22       0.0
# 1   2007      6    23       0.0
# 2   2007      6    26       0.0
# 3   2007      7    27       0.0
# 4   2007      7    28       0.0
# 5   2007      7    29       1.0
# 6   2007      7    30       5.0
# 7   2007      8    31      21.0
# 8   2007      8    32      20.0
# 9   2007      8    33      60.0
# 10  2007      8    34      90.0
# 11  2007      8    35       9.0
# 12  2007      9    36      20.0
# 13  2007      9    37       5.0
# 14  2007      9    38       1.0
# 15  2007      9    39       2.0
# 16  2007     10    40       2.0
# 17  2007     10    41       0.0
# 18  2013      6    23       0.0
# 19  2013      6    24       0.0
# 20  2013      6    25       0.0
# 21  2013      6    26       1.0
# 22  2013      7    28       7.0
# 23  2013      7    29      15.0
# 24  2013      7    30       2.0
# 25  2013      8    31      22.0
# 26  2013      8    32      34.0
# 27  2013      8    33      20.0
# 28  2013      8    34      30.0
# 29  2013      8    35      38.0
# 30  2013      9    36      32.0
# 31  2013      9    37      23.0
# 32  2013      9    38      11.0
# 33  2013      9    39       4.0

# %%
# Create a dataframe for each year with lat long and the cumulative occurence of virus
# col_w.remove('species')
to_keep = ['date', 'latitude', 'longitude', 'wnvpresent']

train_plot = train_2[to_keep].copy()

train_plot['date'] = pd.to_datetime(train_plot['date']) # convert date type
train_plot['year'] = train_plot['date'].dt.year         # create another column of date
train_plot.drop(columns='date', inplace=True)


train_plot = train_plot.groupby(['year', 'latitude', 'longitude']).sum() # collapse rows that have same values in columns col_w
train_plot.reset_index(inplace=True)    # create new df from those collapsed rows

train_plot.rename(columns={'wnvpresent': 'wnvcount', # Rename column names to the appropriate one
                       }, inplace=True)

train_plot_2007 = train_plot.loc[train_plot['year']==2007, :]
train_plot_2009 = train_plot.loc[train_plot['year']==2009, :]
train_plot_2011 = train_plot.loc[train_plot['year']==2011, :]
train_plot_2013 = train_plot.loc[train_plot['year']==2013, :]

# %%
mapdata = np.loadtxt("../BackupData/mapdata_copyright_openstreetmap_contributors.txt/mapdata_copyright_openstreetmap_contributors.txt")
traps = pd.read_csv('../data/train.csv')[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]

aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1)


# Plot for 2007
fig,ax = plt.subplots(figsize=(18,18), nrows=1, ncols=4)
ax[0].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2007 = train_plot_2007.loc[:, ['longitude', 'latitude']]

ax[0].scatter(locations_2007['longitude'], locations_2007['latitude'],
            s=train_plot_2007.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[0].set_title('Traps with WNV - 2007')


# Plot for 2009
ax[1].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2009 = train_plot_2009.loc[:, ['longitude', 'latitude']]

ax[1].scatter(locations_2009['longitude'], locations_2009['latitude'],
            s=train_plot_2009.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[1].set_title('Traps with WNV - 2009')

# Plot for 2011
ax[2].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2011 = train_plot_2011.loc[:, ['longitude', 'latitude']]

ax[2].scatter(locations_2011['longitude'], locations_2011['latitude'],
            s=train_plot_2011.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[2].set_title('Traps with WNV - 2011')

# Plot for 2013
ax[3].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2013 = train_plot_2013.loc[:, ['longitude', 'latitude']]

ax[3].scatter(locations_2013['longitude'], locations_2013['latitude'],
            s=train_plot_2013.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[3].set_title('Traps with WNV - 2013')
# Out:
# Text(0.5, 1.0, 'Traps with WNV - 2013')

# %%
train_plot_2007_top = train_plot_2007.sort_values('wnvcount', ascending=False)[:5]
train_plot_2009_top = train_plot_2009.sort_values('wnvcount', ascending=False)[:5]
train_plot_2011_top = train_plot_2011.sort_values('wnvcount', ascending=False)[:5]
train_plot_2013_top = train_plot_2013.sort_values('wnvcount', ascending=False)[:5]

# %%
# Plot for 2007
fig,ax = plt.subplots(figsize=(18,18), nrows=1, ncols=4)
ax[0].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2007 = train_plot_2007_top.loc[:, ['longitude', 'latitude']]

ax[0].scatter(locations_2007['longitude'], locations_2007['latitude'],
            s=train_plot_2007_top.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[0].set_title('Traps with WNV - 2007')


# Plot for 2009
ax[1].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2009 = train_plot_2009_top.loc[:, ['longitude', 'latitude']]

ax[1].scatter(locations_2009['longitude'], locations_2009['latitude'],
            s=train_plot_2009_top.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[1].set_title('Traps with WNV - 2009')

# Plot for 2011
ax[2].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2011 = train_plot_2011_top.loc[:, ['longitude', 'latitude']]

ax[2].scatter(locations_2011['longitude'], locations_2011['latitude'],
            s=train_plot_2011_top.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[2].set_title('Traps with WNV - 2011')

# Plot for 2013
ax[3].imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations_2013 = train_plot_2013_top.loc[:, ['longitude', 'latitude']]

ax[3].scatter(locations_2013['longitude'], locations_2013['latitude'],
            s=train_plot_2013_top.loc[:, ['wnvcount']]*6,
            alpha=0.8,
            c='red')
ax[3].set_title('Traps with WNV - 2013')

# %%
test.columns
# Out:
# Index(['Id', 'Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy'],
#       dtype='object')

# %%
v = train[['trap', 'longitude', 'latitude']]

# %%
trap = v.groupby(['trap', 'longitude', 'latitude'], as_index=False).count()
