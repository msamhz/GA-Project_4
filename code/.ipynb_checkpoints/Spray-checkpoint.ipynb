# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
spray = pd.read_csv('../data/spray.csv')

# %%
spray.drop_duplicates(inplace=True)

# %%
spray.drop(columns=['Time'], inplace=True)

# %%
spray.columns = spray.columns.str.lower()

# %%
spray
# Out:
#              date   latitude  longitude
# 0      2011-08-29  42.391623 -88.089163
# 1      2011-08-29  42.391348 -88.089163
# 2      2011-08-29  42.391022 -88.089157
# 3      2011-08-29  42.390637 -88.089158
# 4      2011-08-29  42.390410 -88.088858
# ...           ...        ...        ...
# 14830  2013-09-05  42.006587 -87.812355
# 14831  2013-09-05  42.006192 -87.816015
# 14832  2013-09-05  42.006022 -87.817392
# 14833  2013-09-05  42.005453 -87.817423
# 14834  2013-09-05  42.004805 -87.817460
#
# [14294 rows x 3 columns]

# %%
spray['date'] = pd.to_datetime(spray['date'])

# %%
spray.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14294 entries, 0 to 14834
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       14294 non-null  datetime64[ns]
#  1   latitude   14294 non-null  float64
#  2   longitude  14294 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 446.7 KB

# %%
spray.isnull().sum()
# Out:
# date         0
# latitude     0
# longitude    0
# dtype: int64

# %%
spray_date = spray.set_index('date')

# %%
spray['date'].value_counts()
# Out:
# 2013-08-15    2668
# 2013-08-29    2302
# 2013-07-17    2202
# 2013-07-25    1607
# 2013-08-22    1587
# 2011-09-07    1573
# 2013-08-08    1195
# 2013-09-05     924
# 2013-08-16     141
# 2011-08-29      95
# Name: date, dtype: int64

# %%
mapdata = np.loadtxt("../BackupData/mapdata_copyright_openstreetmap_contributors.txt/mapdata_copyright_openstreetmap_contributors.txt")
                     
#traps = pd.read_csv('./datasets/train.csv')[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]

aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88.15, -87.55, 41.65, 42.45)

plt.figure(figsize=(16,20))
plt.imshow(mapdata, 
           cmap=plt.get_cmap('gray'), 
           extent=lon_lat_box, 
           aspect=aspect)

locations = spray_date[['longitude', 'latitude']].values
plt.scatter(locations[:,0], locations[:,1], marker='x', s= 0.1);

# %%
# what is happening?

# %%
# is it working
